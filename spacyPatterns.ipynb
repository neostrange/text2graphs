# %%
import spacy
from spacy.pipeline.span_ruler import SpanRuler

# Load the spaCy model
nlp = spacy.load("en_core_web_trf")

# Define patterns for each label
patterns = {
    "FinancialActivity": [
        {"lower": "stock trading"},
        {"lower": "investment"},
        {"lower": "portfolio management"},
        {"lower": "asset allocation"},
        {"lower": "capital allocation"},
        {"lower": "trading strategy"},
        {"lower": "equity investment"},
        {"lower": "bonds"},
        {"lower": "derivatives trading"},
        {"lower": "forex trading"},
        {"lower": "asset management"},
        {"lower": "share trading"},
        {"lower": "investment strategy"},
        {"lower": "wealth management"},
        {"lower": "commodities trading"},
        {"lower": "futures contracts"},
        {"lower": "securities trading"},
        {"lower": "algorithmic trading"},
        {"lower": "high-frequency trading"},
        {"lower": "options trading"},
        {"lower": "risk management"},
    ],
    "FinancialIndicator": [
        {"lower": "stock price"},
        {"lower": "market index"},
        {"lower": "interest rate"},
        {"lower": "dividend yield"},
        {"lower": "bond yield"},
        {"lower": "volatility index"},
        {"lower": "price-to-earnings ratio"},
        {"lower": "consumer price index"},
        {"lower": "gross domestic product (gdp)"},
        {"lower": "unemployment rate"},
        {"lower": "stock market index"},
        {"lower": "bond rating"},
        {"lower": "inflation rate"},
        {"lower": "exchange rate"},
        {"lower": "treasury yield"},
        {"lower": "credit spread"},
        {"lower": "mortgage rate"},
        {"lower": "yield curve"},
        {"lower": "commodity price index"},
        {"lower": "leading economic index"},
        {"lower": "retail sales index"},
    ],
    "EconomicActivity": [
        {"lower": "trade relations"},
        {"lower": "gdp growth"},
        {"lower": "consumer spending"},
        {"lower": "industrial production"},
        {"lower": "business investment"},
        {"lower": "foreign direct investment"},
        {"lower": "trade deficit"},
        {"lower": "trade surplus"},
        {"lower": "economic development"},
        {"lower": "employment rate"},
        {"lower": "housing starts"},
        {"lower": "business sentiment"},
        {"lower": "consumer confidence"},
        {"lower": "retail sales"},
        {"lower": "business investment"},
        {"lower": "factory orders"},
        {"lower": "trade balance"},
        {"lower": "export-import volume"},
        {"lower": "manufacturing pmi"},
    ],
    "EconomicPolicy": [
        {"lower": "monetary policy"},
        {"lower": "fiscal policy"},
        {"lower": "interest rate policy"},
        {"lower": "tax policy"},
        {"lower": "budgetary policy"},
        {"lower": "regulatory policy"},
        {"lower": "economic stimulus"},
        {"lower": "inflation targeting"},
        {"lower": "interest rate decision"},
        {"lower": "quantitative easing"},
        {"lower": "fiscal stimulus"},
        {"lower": "central bank intervention"},
        {"lower": "austerity measures"},
        {"lower": "tax reform"},
        {"lower": "tariff policy"},
        {"lower": "trade agreement"},
        {"lower": "regulatory reform"},
        {"lower": "budget deficit reduction"},
    ],
    "EconomicSituation": [
        {"lower": "recession"},
        {"lower": "inflation"},
        {"lower": "deflation"},
        {"lower": "market volatility"},
        {"lower": "economic downturn"},
        {"lower": "economic recovery"},
        {"lower": "stagflation"},
        {"lower": "hyperinflation"},
        {"lower": "economic stability"},
        {"lower": "economic indicators"},
        {"lower": "economic recession"},
        {"lower": "economic recovery"},
        {"lower": "economic slowdown"},
        {"lower": "boom-bust cycle"},
        {"lower": "deflationary pressures"},
        {"lower": "economic expansion"},
        {"lower": "economic stagnation"},
        {"lower": "economic resilience"},
        {"lower": "fiscal imbalance"},
        {"lower": "debt crisis"},
    ],
    "EconomicEntity": [
        {"lower": "financial institution"},
        {"lower": "multinational corporation"},
        {"lower": "investment bank"},
        {"lower": "commercial bank"},
        {"lower": "hedge fund"},
        {"lower": "sovereign wealth fund"},
        {"lower": "credit rating agency"},
        {"lower": "central bank"},
        {"lower": "pension fund"},
        {"lower": "investment firm"},
        {"lower": "venture capitalist"},
        {"lower": "angel investor"},
        {"lower": "mutual fund"},
        {"lower": "credit union"},
        {"lower": "brokerage firm"},
        {"lower": "insurance company"},
        {"lower": "financial regulator"},
        {"lower": "sovereign debt holder"},
        {"lower": "corporate bondholder"},
        {"lower": "institutional investor"},
    ],
    "GeographicRegion": [
        {"lower": "developed economies"},
        {"lower": "emerging markets"},
        {"lower": "developed countries"},
        {"lower": "developing nations"},
        {"lower": "global regions (north america, asia-pacific, europe, etc.)"},
        {"lower": "economic zones"},
        {"lower": "free trade zones"},
        {"lower": "emerging markets"},
        {"lower": "developing economies"},
        {"lower": "global economies"},
        {"lower": "regional blocs (eu, asean, nafta)"},
        {"lower": "economic zones"},
        {"lower": "special economic zones"},
        {"lower": "economic corridors"},
        {"lower": "economic blocs"},
        {"lower": "economic alliances"},
    ],
}

# Create a SpanRuler and add patterns for each label
ruler = SpanRuler(nlp)
for label, label_patterns in patterns.items():
    ruler.add_patterns(label_patterns)

# Add the SpanRuler to the pipeline
nlp.add_pipe(ruler, before="ner")

# Process the text
text = "Stock trading and GDP growth are important aspects of the economic situation. Developed economies often have advanced financial institutions."
doc = nlp(text)

# Print the matched spans and their labels
for span in doc.ents:
    print(span.text, span.label_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 163
#     161 ruler = SpanRuler(nlp)
#     162 for label, label_patterns in patterns.items():
# --> 163     ruler.add_patterns(label_patterns)
#     165 # Add the SpanRuler to the pipeline
#     166 nlp.add_pipe(ruler, before="ner")
#
# File ~/environments/text2graphs/venv/lib/python3.10/site-packages/spacy/pipeline/span_ruler.py:450, in SpanRuler.add_patterns(self, patterns)
#     448 phrase_pattern_texts = []
#     449 for entry in patterns:
# --> 450     p_label = cast(str, entry["label"])
#     451     p_id = cast(str, entry.get("id", ""))
#     452     label = repr((p_label, p_id))
#
# KeyError: 'label'

# %%
import spacy

nlp = spacy.load("en_core_web_trf")
#ruler = nlp.add_pipe("entity_ruler", after='ner')
patterns = [
    {"label": "FinancialActivity", "pattern": "stock trading"},
    {"label": "FinancialActivity", "pattern": "investment"},
    {"label": "FinancialActivity", "pattern": "portfolio management"},
    {"label": "FinancialActivity", "pattern": "asset allocation"},
    {"label": "FinancialActivity", "pattern": "capital allocation"},
    {"label": "FinancialActivity", "pattern": "trading strategy"},
    {"label": "FinancialActivity", "pattern": "equity investment"},
    {"label": "FinancialActivity", "pattern": "bonds"},
    {"label": "FinancialActivity", "pattern": "derivatives trading"},
    {"label": "FinancialActivity", "pattern": "forex trading"},
    {"label": "FinancialActivity", "pattern": "asset management"},
    {"label": "FinancialActivity", "pattern": "share trading"},
    {"label": "FinancialActivity", "pattern": "investment strategy"},
    {"label": "FinancialActivity", "pattern": "wealth management"},
    {"label": "FinancialActivity", "pattern": "commodities trading"},
    {"label": "FinancialActivity", "pattern": "futures contracts"},
    {"label": "FinancialActivity", "pattern": "securities trading"},
    {"label": "FinancialActivity", "pattern": "algorithmic trading"},
    {"label": "FinancialActivity", "pattern": "high-frequency trading"},
    {"label": "FinancialActivity", "pattern": "options trading"},
    {"label": "FinancialActivity", "pattern": "risk management"},
    {"label": "FinancialIndicator", "pattern": "stock price"},
    {"label": "FinancialIndicator", "pattern": "market index"},
    {"label": "FinancialIndicator", "pattern": "interest rate"},
    {"label": "FinancialIndicator", "pattern": "dividend yield"},
    {"label": "FinancialIndicator", "pattern": "bond yield"},
    {"label": "FinancialIndicator", "pattern": "volatility index"},
    {"label": "FinancialIndicator", "pattern": "price-to-earnings ratio"},
    {"label": "FinancialIndicator", "pattern": "consumer price index"},
    {"label": "FinancialIndicator", "pattern": "gross domestic product (gdp)"},
    {"label": "FinancialIndicator", "pattern": "unemployment rate"},
    {"label": "FinancialIndicator", "pattern": "stock market index"},
    {"label": "FinancialIndicator", "pattern": "bond rating"},
    {"label": "FinancialIndicator", "pattern": "inflation rate"},
    {"label": "FinancialIndicator", "pattern": "exchange rate"},
    {"label": "FinancialIndicator", "pattern": "treasury yield"},
    {"label": "FinancialIndicator", "pattern": "credit spread"},
    {"label": "FinancialIndicator", "pattern": "mortgage rate"},
    {"label": "FinancialIndicator", "pattern": "yield curve"},
    {"label": "FinancialIndicator", "pattern": "commodity price index"},
    {"label": "FinancialIndicator", "pattern": "leading economic index"},
    {"label": "FinancialIndicator", "pattern": "retail sales index"},
    {"label": "EconomicActivity", "pattern": "trade relations"},
    {"label": "EconomicActivity", "pattern": "gdp growth"},
    {"label": "EconomicActivity", "pattern": "consumer spending"},
    {"label": "EconomicActivity", "pattern": "industrial production"},
    {"label": "EconomicActivity", "pattern": "business investment"},
    {"label": "EconomicActivity", "pattern": "foreign direct investment"},
    {"label": "EconomicActivity", "pattern": "trade deficit"},
    {"label": "EconomicActivity", "pattern": "trade surplus"},
    {"label": "EconomicActivity", "pattern": "economic development"},
    {"label": "EconomicActivity", "pattern": "employment rate"},
    {"label": "EconomicActivity", "pattern": "housing starts"},
    {"label": "EconomicActivity", "pattern": "business sentiment"},
    {"label": "EconomicActivity", "pattern": "consumer confidence"},
    {"label": "EconomicActivity", "pattern": "retail sales"},
    {"label": "EconomicActivity", "pattern": "business investment"},
    {"label": "EconomicActivity", "pattern": "factory orders"},
    {"label": "EconomicActivity", "pattern": "trade balance"},
    {"label": "EconomicActivity", "pattern": "export-import volume"},
    {"label": "EconomicActivity", "pattern": "manufacturing pmi"},
    {"label": "EconomicPolicy", "pattern": "monetary policy"},
    {"label": "EconomicPolicy", "pattern": "fiscal policy"},
    {"label": "EconomicPolicy", "pattern": "interest rate policy"},
    {"label": "EconomicPolicy", "pattern": "tax policy"},
    {"label": "EconomicPolicy", "pattern": "budgetary policy"},
    {"label": "EconomicPolicy", "pattern": "regulatory policy"},
    {"label": "EconomicPolicy", "pattern": "economic stimulus"},
    {"label": "EconomicPolicy", "pattern": "inflation targeting"},
    {"label": "EconomicPolicy", "pattern": "interest rate decision"},
    {"label": "EconomicPolicy", "pattern": "quantitative easing"},
    {"label": "EconomicPolicy", "pattern": "fiscal stimulus"},
    {"label": "EconomicPolicy", "pattern": "central bank intervention"},
    {"label": "EconomicPolicy", "pattern": "austerity measures"},
    {"label": "EconomicPolicy", "pattern": "tax reform"},
    {"label": "EconomicPolicy", "pattern": "tariff policy"},
    {"label": "EconomicPolicy", "pattern": "trade agreement"},
    {"label": "EconomicPolicy", "pattern": "regulatory reform"},
    {"label": "EconomicPolicy", "pattern": "budget deficit reduction"},
    {"label": "EconomicSituation", "pattern": "recession"},
    {"label": "EconomicSituation", "pattern": "inflation"},
    {"label": "EconomicSituation", "pattern": "deflation"},
    {"label": "EconomicSituation", "pattern": "market volatility"},
    {"label": "EconomicSituation", "pattern": "economic downturn"},
    {"label": "EconomicSituation", "pattern": "economic recovery"},
    {"label": "EconomicSituation", "pattern": "stagflation"},
    {"label": "EconomicSituation", "pattern": "hyperinflation"},
    {"label": "EconomicSituation", "pattern": "economic stability"},
    {"label": "EconomicSituation", "pattern": "economic indicators"},
    {"label": "EconomicSituation", "pattern": "economic recession"},
    {"label": "EconomicSituation", "pattern": "economic recovery"},
    {"label": "EconomicSituation", "pattern": "economic slowdown"},
    {"label": "EconomicSituation", "pattern": "boom-bust cycle"},
    {"label": "EconomicSituation", "pattern": "deflationary pressures"},
    {"label": "EconomicSituation", "pattern": "economic expansion"},
    {"label": "EconomicSituation", "pattern": "economic stagnation"},
    {"label": "EconomicSituation", "pattern": "economic resilience"},
    {"label": "EconomicSituation", "pattern": "fiscal imbalance"},
    {"label": "EconomicSituation", "pattern": "debt crisis"},
    {"label": "EconomicEntity", "pattern": "financial institution"},
    {"label": "EconomicEntity", "pattern": "multinational corporation"},
    {"label": "EconomicEntity", "pattern": "investment bank"},
    {"label": "EconomicEntity", "pattern": "commercial bank"},
    {"label": "EconomicEntity", "pattern": "hedge fund"},
    {"label": "EconomicEntity", "pattern": "sovereign wealth fund"},
    {"label": "EconomicEntity", "pattern": "credit rating agency"},
    {"label": "EconomicEntity", "pattern": "central bank"},
    {"label": "EconomicEntity", "pattern": "pension fund"},
    {"label": "EconomicEntity", "pattern": "investment firm"},
    {"label": "EconomicEntity", "pattern": "venture capitalist"},
    {"label": "EconomicEntity", "pattern": "angel investor"},
    {"label": "EconomicEntity", "pattern": "mutual fund"},
    {"label": "EconomicEntity", "pattern": "credit union"},
    {"label": "EconomicEntity", "pattern": "brokerage firm"},
    {"label": "EconomicEntity", "pattern": "insurance company"},
    {"label": "EconomicEntity", "pattern": "financial regulator"},
    {"label": "EconomicEntity", "pattern": "sovereign debt holder"},
    {"label": "EconomicEntity", "pattern": "corporate bondholder"},
    {"label": "EconomicEntity", "pattern": "institutional investor"},
    {"label": "GeographicRegion", "pattern": "developed economies"},
    {"label": "GeographicRegion", "pattern": "emerging markets"},
    {"label": "GeographicRegion", "pattern": "developed countries"},
    {"label": "GeographicRegion", "pattern": "developing nations"},
    {"label": "GeographicRegion", "pattern": "global regions (north america, asia-pacific, europe, etc.)"},
    {"label": "GeographicRegion", "pattern": "economic zones"},
    {"label": "GeographicRegion", "pattern": "free trade zones"},
    {"label": "GeographicRegion", "pattern": "emerging markets"},
    {"label": "GeographicRegion", "pattern": "developing economies"},
    {"label": "GeographicRegion", "pattern": "global economies"},
    {"label": "GeographicRegion", "pattern": "regional blocs (eu, asean, nafta)"},
    {"label": "GeographicRegion", "pattern": "economic zones"},
    {"label": "GeographicRegion", "pattern": "special economic zones"},
    {"label": "GeographicRegion", "pattern": "economic corridors"},
    {"label": "GeographicRegion", "pattern": "economic blocs"},
    {"label": "GeographicRegion", "pattern": "economic alliances"},
    {"label": "GeographicRegion", "pattern": [{"LOWER": "global"}, {"LOWER": "stock"}, {"LOWER": "markets"}]},
    {"label": "EconomicSituation", "pattern": [{"LOWER": "sub-prime"}, {"LOWER": "mortgage"}, {"LOWER": "crisis"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "dow"}, {"LOWER": "jones"}, {"LOWER": "industrial"}, {"LOWER": "average"}]},
    {"label": "GeographicRegion", "pattern": [{"LOWER": "uk"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "ftse-100"}, {"LOWER": "index"}]},
    {"label": "GeographicRegion", "pattern": [{"LOWER": "japan"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "nikkei"}, {"LOWER": "225"}]},
]

#ruler.add_patterns(patterns)

doc = nlp("Global stock markets fell today, in a mass sell-off stemming from the sub-prime mortgage crisis in the United States. The Dow Jones Industrial Average rebounded late in the day after falling more than 250 points, ending the day down about 31 points. The UK's FTSE-100 index fell 232.90 points to 6038.30, and Japan's Nikkei 225 fell 406.51 points to 16764.09. ")
#print([(span.text, span.label_) for span in doc.spans["ruler"]])
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# today DATE
# the United States GPE
# late in TIME
# more than 250 CARDINAL
# the day DATE
# about 31 CARDINAL
# UK GPE
# 232.90 CARDINAL
# 6038.30 CARDINAL
# Japan GPE
# 406.51 CARDINAL
# 16764.09 CARDINAL

# %%
import spacy

nlp = spacy.load("en_core_web_trf")
#ruler = nlp.add_pipe("entity_ruler", after='ner')
ruler = nlp.add_pipe("span_ruler")
patterns = [
    {"label": "FinancialActivity", "pattern": "stock trading"},
    {"label": "FinancialActivity", "pattern": "investment"},
    {"label": "FinancialActivity", "pattern": "portfolio management"},
    {"label": "FinancialActivity", "pattern": "asset allocation"},
    {"label": "FinancialActivity", "pattern": "capital allocation"},
    {"label": "FinancialActivity", "pattern": "trading strategy"},
    {"label": "FinancialActivity", "pattern": "equity investment"},
    {"label": "FinancialActivity", "pattern": "bonds"},
    {"label": "FinancialActivity", "pattern": "derivatives trading"},
    {"label": "FinancialActivity", "pattern": "forex trading"},
    {"label": "FinancialActivity", "pattern": "asset management"},
    {"label": "FinancialActivity", "pattern": "share trading"},
    {"label": "FinancialActivity", "pattern": "investment strategy"},
    {"label": "FinancialActivity", "pattern": "wealth management"},
    {"label": "FinancialActivity", "pattern": "commodities trading"},
    {"label": "FinancialActivity", "pattern": "futures contracts"},
    {"label": "FinancialActivity", "pattern": "securities trading"},
    {"label": "FinancialActivity", "pattern": "algorithmic trading"},
    {"label": "FinancialActivity", "pattern": "high-frequency trading"},
    {"label": "FinancialActivity", "pattern": "options trading"},
    {"label": "FinancialActivity", "pattern": "risk management"},
    {"label": "FinancialIndicator", "pattern": "stock price"},
    {"label": "FinancialIndicator", "pattern": "market index"},
    {"label": "FinancialIndicator", "pattern": "interest rate"},
    {"label": "FinancialIndicator", "pattern": "dividend yield"},
    {"label": "FinancialIndicator", "pattern": "bond yield"},
    {"label": "FinancialIndicator", "pattern": "volatility index"},
    {"label": "FinancialIndicator", "pattern": "price-to-earnings ratio"},
    {"label": "FinancialIndicator", "pattern": "consumer price index"},
    {"label": "FinancialIndicator", "pattern": "gross domestic product (gdp)"},
    {"label": "FinancialIndicator", "pattern": "unemployment rate"},
    {"label": "FinancialIndicator", "pattern": "stock market index"},
    {"label": "FinancialIndicator", "pattern": "bond rating"},
    {"label": "FinancialIndicator", "pattern": "inflation rate"},
    {"label": "FinancialIndicator", "pattern": "exchange rate"},
    {"label": "FinancialIndicator", "pattern": "treasury yield"},
    {"label": "FinancialIndicator", "pattern": "credit spread"},
    {"label": "FinancialIndicator", "pattern": "mortgage rate"},
    {"label": "FinancialIndicator", "pattern": "yield curve"},
    {"label": "FinancialIndicator", "pattern": "commodity price index"},
    {"label": "FinancialIndicator", "pattern": "leading economic index"},
    {"label": "FinancialIndicator", "pattern": "retail sales index"},
    {"label": "EconomicActivity", "pattern": "trade relations"},
    {"label": "EconomicActivity", "pattern": "gdp growth"},
    {"label": "EconomicActivity", "pattern": "consumer spending"},
    {"label": "EconomicActivity", "pattern": "industrial production"},
    {"label": "EconomicActivity", "pattern": "business investment"},
    {"label": "EconomicActivity", "pattern": "foreign direct investment"},
    {"label": "EconomicActivity", "pattern": "trade deficit"},
    {"label": "EconomicActivity", "pattern": "trade surplus"},
    {"label": "EconomicActivity", "pattern": "economic development"},
    {"label": "EconomicActivity", "pattern": "employment rate"},
    {"label": "EconomicActivity", "pattern": "housing starts"},
    {"label": "EconomicActivity", "pattern": "business sentiment"},
    {"label": "EconomicActivity", "pattern": "consumer confidence"},
    {"label": "EconomicActivity", "pattern": "retail sales"},
    {"label": "EconomicActivity", "pattern": "business investment"},
    {"label": "EconomicActivity", "pattern": "factory orders"},
    {"label": "EconomicActivity", "pattern": "trade balance"},
    {"label": "EconomicActivity", "pattern": "export-import volume"},
    {"label": "EconomicActivity", "pattern": "manufacturing pmi"},
    {"label": "EconomicPolicy", "pattern": "monetary policy"},
    {"label": "EconomicPolicy", "pattern": "fiscal policy"},
    {"label": "EconomicPolicy", "pattern": "interest rate policy"},
    {"label": "EconomicPolicy", "pattern": "tax policy"},
    {"label": "EconomicPolicy", "pattern": "budgetary policy"},
    {"label": "EconomicPolicy", "pattern": "regulatory policy"},
    {"label": "EconomicPolicy", "pattern": "economic stimulus"},
    {"label": "EconomicPolicy", "pattern": "inflation targeting"},
    {"label": "EconomicPolicy", "pattern": "interest rate decision"},
    {"label": "EconomicPolicy", "pattern": "quantitative easing"},
    {"label": "EconomicPolicy", "pattern": "fiscal stimulus"},
    {"label": "EconomicPolicy", "pattern": "central bank intervention"},
    {"label": "EconomicPolicy", "pattern": "austerity measures"},
    {"label": "EconomicPolicy", "pattern": "tax reform"},
    {"label": "EconomicPolicy", "pattern": "tariff policy"},
    {"label": "EconomicPolicy", "pattern": "trade agreement"},
    {"label": "EconomicPolicy", "pattern": "regulatory reform"},
    {"label": "EconomicPolicy", "pattern": "budget deficit reduction"},
    {"label": "EconomicSituation", "pattern": "recession"},
    {"label": "EconomicSituation", "pattern": "inflation"},
    {"label": "EconomicSituation", "pattern": "deflation"},
    {"label": "EconomicSituation", "pattern": "market volatility"},
    {"label": "EconomicSituation", "pattern": "economic downturn"},
    {"label": "EconomicSituation", "pattern": "economic recovery"},
    {"label": "EconomicSituation", "pattern": "stagflation"},
    {"label": "EconomicSituation", "pattern": "hyperinflation"},
    {"label": "EconomicSituation", "pattern": "economic stability"},
    {"label": "EconomicSituation", "pattern": "economic indicators"},
    {"label": "EconomicSituation", "pattern": "economic recession"},
    {"label": "EconomicSituation", "pattern": "economic recovery"},
    {"label": "EconomicSituation", "pattern": "economic slowdown"},
    {"label": "EconomicSituation", "pattern": "boom-bust cycle"},
    {"label": "EconomicSituation", "pattern": "deflationary pressures"},
    {"label": "EconomicSituation", "pattern": "economic expansion"},
    {"label": "EconomicSituation", "pattern": "economic stagnation"},
    {"label": "EconomicSituation", "pattern": "economic resilience"},
    {"label": "EconomicSituation", "pattern": "fiscal imbalance"},
    {"label": "EconomicSituation", "pattern": "debt crisis"},
    {"label": "EconomicEntity", "pattern": "financial institution"},
    {"label": "EconomicEntity", "pattern": "multinational corporation"},
    {"label": "EconomicEntity", "pattern": "investment bank"},
    {"label": "EconomicEntity", "pattern": "commercial bank"},
    {"label": "EconomicEntity", "pattern": "hedge fund"},
    {"label": "EconomicEntity", "pattern": "sovereign wealth fund"},
    {"label": "EconomicEntity", "pattern": "credit rating agency"},
    {"label": "EconomicEntity", "pattern": "central bank"},
    {"label": "EconomicEntity", "pattern": "pension fund"},
    {"label": "EconomicEntity", "pattern": "investment firm"},
    {"label": "EconomicEntity", "pattern": "venture capitalist"},
    {"label": "EconomicEntity", "pattern": "angel investor"},
    {"label": "EconomicEntity", "pattern": "mutual fund"},
    {"label": "EconomicEntity", "pattern": "credit union"},
    {"label": "EconomicEntity", "pattern": "brokerage firm"},
    {"label": "EconomicEntity", "pattern": "insurance company"},
    {"label": "EconomicEntity", "pattern": "financial regulator"},
    {"label": "EconomicEntity", "pattern": "sovereign debt holder"},
    {"label": "EconomicEntity", "pattern": "corporate bondholder"},
    {"label": "EconomicEntity", "pattern": "institutional investor"},
    {"label": "GeographicRegion", "pattern": "developed economies"},
    {"label": "GeographicRegion", "pattern": "emerging markets"},
    {"label": "GeographicRegion", "pattern": "developed countries"},
    {"label": "GeographicRegion", "pattern": "developing nations"},
    {"label": "GeographicRegion", "pattern": "global regions (north america, asia-pacific, europe, etc.)"},
    {"label": "GeographicRegion", "pattern": "economic zones"},
    {"label": "GeographicRegion", "pattern": "free trade zones"},
    {"label": "GeographicRegion", "pattern": "emerging markets"},
    {"label": "GeographicRegion", "pattern": "developing economies"},
    {"label": "GeographicRegion", "pattern": "global economies"},
    {"label": "GeographicRegion", "pattern": "regional blocs (eu, asean, nafta)"},
    {"label": "GeographicRegion", "pattern": "economic zones"},
    {"label": "GeographicRegion", "pattern": "special economic zones"},
    {"label": "GeographicRegion", "pattern": "economic corridors"},
    {"label": "GeographicRegion", "pattern": "economic blocs"},
    {"label": "GeographicRegion", "pattern": "economic alliances"},
    {"label": "GeographicRegion", "pattern": "united states"},
    {"label": "FinancialActivity", "pattern": [{"LOWER": "global"}, {"LOWER": "stock"}, {"LOWER": "markets"}]},
    {"label": "EconomicSituation", "pattern": [{"LOWER": "sub-prime"}, {"LOWER": "mortgage"}, {"LOWER": "crisis"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "dow"}, {"LOWER": "jones"}, {"LOWER": "industrial"}, {"LOWER": "average"}]},
    {"label": "GeographicRegion", "pattern": [{"LOWER": "uk"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "ftse-100"}, {"LOWER": "index"}]},
    {"label": "GeographicRegion", "pattern": [{"LOWER": "japan"}]},
    {"label": "FinancialIndicator", "pattern": [{"LOWER": "nikkei"}, {"LOWER": "225"}]},
]

ruler.add_patterns(patterns)

doc = nlp("Global stock markets fell today, in a mass sell-off stemming from the sub-prime mortgage crisis in the United States. The Dow Jones Industrial Average rebounded late in the day after falling more than 250 points, ending the day down about 31 points. The UK's FTSE-100 index fell 232.90 points to 6038.30, and Japan's Nikkei 225 fell 406.51 points to 16764.09. ")
#print([(span.text, span.label_) for span in doc.spans["ruler"]])
extended_ents = doc.spans["ruler"]
extended_ents.extend(doc.ents)

for ent in extended_ents:
    print (ent.text, ent.label_)
# Out:
# Global stock markets GeographicRegion
# Dow Jones Industrial Average FinancialIndicator
# UK GeographicRegion
# FTSE-100 index FinancialIndicator
# Japan GeographicRegion
# Nikkei 225 FinancialIndicator
# today DATE
# the United States GPE
# late in TIME
# more than 250 CARDINAL
# the day DATE
# about 31 CARDINAL
# UK GPE
# 232.90 CARDINAL
# 6038.30 CARDINAL
# Japan GPE
# 406.51 CARDINAL
# 16764.09 CARDINAL

# %%
import spacy
from spacy.lang.en import English
from spacy.tokens import Doc, Span

# Load the spaCy model
nlp = spacy.load("en_core_web_trf")

# Create a SpanRuler
ruler = nlp.add_pipe("span_ruler")

# Define rules based on the provided specifications

# Rule for nominal pre-modifier
nominal_modifier_rule = {"label": "NOM", "pattern": [{"POS": "NOUN"}]}
ruler.add_patterns([nominal_modifier_rule])

# Rule for proper name pre-modifier
proper_name_modifier_rule = {"label": "NAM", "pattern": [{"POS": "PROPN"}]}
ruler.add_patterns([proper_name_modifier_rule])

# Rule for adjective derived from a proper noun
adj_proper_name_rule = {"label": "PRE.NAM", "pattern": [{"POS": "ADJ"}, {"POS": "PROPN"}]}
ruler.add_patterns([adj_proper_name_rule])

# Rule for adjective derived from a common noun
adj_common_noun_rule = {"label": "PRE.NOM", "pattern": [{"POS": "ADJ"}, {"POS": "NOUN"}]}
ruler.add_patterns([adj_common_noun_rule])

# Rule for titles, honorifics, and positions
titles_honorifics_rule = {"label": "PER.PRE", "pattern": [{"POS": {"in": ["TITLE", "HONORIFIC", "POSITION"]}}]}
ruler.add_patterns([titles_honorifics_rule])

# Rule for entities with both nominal and proper name pre-modifiers
both_modifiers_rule = {"label": "PER.USP.NOM", "pattern": [{"POS": {"in": ["ADJ", "NOUN"]}}, {"POS": "NOUN"}, {"POS": "PROPN"}]}
ruler.add_patterns([both_modifiers_rule])

# Example text
text = "In European traditions, mountainous regions, US President Obama, Pope John Paul II, and the next President are mentioned."

# Process the text using spaCy
doc = nlp(text)

# Get the annotated spans from the Doc
annotated_spans = doc.spans["ruler"]

# Process the annotated spans
for span in annotated_spans:
    print(f"Entity found: {span.text}, Label: {span.label_}")
# Out:
# Entity found: European traditions, Label: PRE.NOM
# Entity found: traditions, Label: NOM
# Entity found: mountainous regions, Label: PRE.NOM
# Entity found: regions, Label: NOM
# Entity found: US, Label: NAM
# Entity found: President, Label: NAM
# Entity found: Obama, Label: NAM
# Entity found: Pope, Label: NAM
# Entity found: John, Label: NAM
# Entity found: Paul, Label: NAM
# Entity found: II, Label: NAM
# Entity found: next President, Label: PRE.NAM
# Entity found: President, Label: NAM

# %%
import spacy
from spacy.lang.en import English
from spacy.tokens import Doc, Span

# Load the spaCy model
nlp = spacy.load("en_core_web_trf")

# Create a SpanRuler
ruler = nlp.add_pipe("span_ruler")

# Define rules based on the provided specifications

# Rule for nominal pre-modifier
nominal_modifier_rule = {"label": "NOM", "pattern": [{"POS": "NOUN"}]}
ruler.add_patterns([nominal_modifier_rule])

# Rule for proper name pre-modifier
proper_name_modifier_rule = {"label": "NAM", "pattern": [{"POS": "PROPN"}]}
ruler.add_patterns([proper_name_modifier_rule])

# Rule for adjective derived from a proper noun
adj_proper_name_rule = {"label": "PRE.NAM", "pattern": [{"POS": "ADJ"}, {"POS": "PROPN"}]}
ruler.add_patterns([adj_proper_name_rule])

# Rule for adjective derived from a common noun
adj_common_noun_rule = {"label": "PRE.NOM", "pattern": [{"POS": "ADJ"}, {"POS": "NOUN"}]}
ruler.add_patterns([adj_common_noun_rule])

# Rule for titles, honorifics, and positions
titles_honorifics_rule = {"label": "PER.PRE", "pattern": [{"POS": {"in": ["TITLE", "HONORIFIC", "POSITION"]}}]}
ruler.add_patterns([titles_honorifics_rule])

# Rule for entities with both nominal and proper name pre-modifiers
both_modifiers_rule = {
    "label": "PER.USP.NOM",
    "pattern": [{"POS": {"in": ["ADJ", "NOUN"]}}, {"POS": "NOUN"}, {"POS": "PROPN"}],
}
ruler.add_patterns([both_modifiers_rule])

# Example text
text = "In European traditions, mountainous regions, US President Obama, Pope John Paul II, and the next President are mentioned."

# Process the text using spaCy
doc = nlp(text)

# Get the annotated spans from the Doc
spans = doc.spans['ruler']

# Combine entities with their pre-modifiers
combined_spans = []
for span in spans:
    if span.root != span.root.head:  # Check if the span is not the root
        pre_modifier = doc[span.start - 1]
        combined_spans.append(Span(doc, pre_modifier.i, span.end, span.label_))
    else:
        combined_spans.append(span)

# Process the annotated spans
for span in combined_spans:
    print(f"Entity found: {span.text}, Label: {span.label_}")
# Out:
# Entity found: In European traditions, Label: PRE.NOM
# Entity found: European traditions, Label: NOM
# Entity found: , mountainous regions, Label: PRE.NOM
# Entity found: mountainous regions, Label: NOM
# Entity found: , US, Label: NAM
# Entity found: US President, Label: NAM
# Entity found: President Obama, Label: NAM
# Entity found: , Pope, Label: NAM
# Entity found: Pope John, Label: NAM
# Entity found: John Paul, Label: NAM
# Entity found: Paul II, Label: NAM
# Entity found: the next President, Label: PRE.NAM
# Entity found: next President, Label: NAM

# %%
import spacy

nlp = spacy.load("en_core_web_trf")

doc = nlp("""He had been baking the cake.""")

for token in doc:
    print(token.text, ': ',token.morph)
# Out:
# He :  Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs
# had :  Tense=Past|VerbForm=Fin
# been :  Tense=Past|VerbForm=Part
# baking :  Aspect=Prog|Tense=Pres|VerbForm=Part
# the :  Definite=Def|PronType=Art
# cake :  Number=Sing
# . :  PunctType=Peri
